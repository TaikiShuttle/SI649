# %%
import pandas as pd

df = pd.read_csv('insurance.txt', sep = '\t')

# %%
df = df.iloc[1: 52,:]
df['Estimate (%)'] = df['Estimate (%)'].astype(float)
df.to_csv('insurance.csv', index = False)

# %%
df2 = pd.read_csv('income.txt', sep = '\t')

df2 = df2.iloc[1: 52,:]
df2['Estimate ($)'] = df2['Estimate ($)'].apply(lambda x: x.replace(',', '')).astype(int)
df2.to_csv('income.csv', index = False)

# %%
df2
# Out:
#                 Location  Estimate ($)   90% MOE Base Population Sample Size
# 1                ALABAMA         40400  ±  2,840          94,000         915
# 2                 ALASKA         46800  ±  6,290          12,000         107
# 3                ARIZONA         39200  ±  2,520         116,000       1,141
# 4               ARKANSAS         35400  ±  3,220          57,000         599
# 5             CALIFORNIA         48500  ±  1,830         440,000       4,390
# 6               COLORADO         47500  ±  3,690          88,000         843
# 7            CONNECTICUT         50500  ±  5,240          45,000         444
# 8               DELAWARE         50500  ±  8,440          19,000         148
# 9   DISTRICT OF COLUMBIA         60600  ± 14,840          10,000          95
# 10               FLORIDA         38400  ±  1,700         298,000       2,940
# 11               GEORGIA         40400  ±  2,360         170,000       1,681
# ...

# %%
df2 = pd.read_csv('healthy.txt', sep = '\t')

df2 = df2.iloc[1: 52,:]
df2['Estimate (%)'] = df2['Estimate (%)']
df2.to_csv('healthy.csv', index = False)
df2
# Out:
#                 Location  Estimate (%) 90% MOE Base Population Sample Size
# 1                ALABAMA          14.6  ± 0.53       2,317,200      21,658
# 2                 ALASKA          15.2  ± 1.80         384,100       3,268
# 3                ARIZONA          15.6  ± 0.70       3,527,900      32,358
# 4               ARKANSAS          14.0  ± 0.73       1,375,300      12,923
# 5             CALIFORNIA          11.2  ± 0.21      21,138,700     196,327
# 6               COLORADO          10.6  ± 0.51       3,107,200      29,540
# 7            CONNECTICUT           8.6  ± 0.47       1,844,900      17,768
# 8               DELAWARE           9.5  ± 1.19         469,400       4,306
# 9   DISTRICT OF COLUMBIA           4.2  ± 0.93         407,200       4,019
# 10               FLORIDA          19.7  ± 0.36      10,583,800      95,803
# 11               GEORGIA          18.6  ± 0.39       5,357,500      48,740
# ...
