# %%
import pandas as pd
import numpy as np
import altair as alt
import streamlit as st

# %%
df1 = pd.read_csv('insurance.csv')
df2 = pd.read_csv('income.csv')

df = pd.merge(df1, df2, on='Location')
df = df[['Location', 'Estimate (%)',  'Estimate ($)']]
df.columns = ['Location', 'Insurance_rate', 'Income']
df
# Out:
#                 Location  Insurance_rate  Income
# 0                ALABAMA            14.5   40400
# 1                 ALASKA            11.1   46800
# 2                ARIZONA            11.0   39200
# 3               ARKANSAS             7.4   35400
# 4             CALIFORNIA             7.6   48500
# 5               COLORADO             8.1   47500
# 6            CONNECTICUT             5.0   50500
# 7               DELAWARE             7.0   50500
# 8   DISTRICT OF COLUMBIA             2.9   60600
# 9                FLORIDA            15.1   38400
# 10               GEORGIA            16.5   40400
# 11                HAWAII             6.7   50500
# 12                 IDAHO            11.7   40400
# 13              ILLINOIS             7.4   43900
# 14               INDIANA             8.9   40400
# 15                  IOWA             5.1   40400
# 16                KANSAS            14.5   40400
# 17              KENTUCKY             4.9   37400
# 18             LOUISIANA             8.5   40400
# 19                 MAINE             7.6   39800
# 20              MARYLAND             5.5   54500
# 21         MASSACHUSETTS             3.6   52500
# 22              MICHIGAN             6.3   40400
# 23             MINNESOTA             6.6   48500
# 24           MISSISSIPPI            16.5   32300
# 25              MISSOURI            14.5   37400
# 26               MONTANA            10.6   37400
# 27              NEBRASKA            17.4   48500
# 28                NEVADA            12.0   40400
# 29         NEW HAMPSHIRE             8.8   51500
# 30            NEW JERSEY             7.6   50500
# 31            NEW MEXICO             9.3   38800
# 32              NEW YORK             4.5   48500
# 33        NORTH CAROLINA            14.1   38400
# 34          NORTH DAKOTA            12.6   44400
# 35                  OHIO             8.0   40400
# 36              OKLAHOMA            21.4   38400
# 37                OREGON             7.4   40400
# 38          PENNSYLVANIA             6.6   40400
# 39          RHODE ISLAND             3.0   50500
# 40        SOUTH CAROLINA            15.1   40400
# 41          SOUTH DAKOTA            17.7   36400
# 42             TENNESSEE            13.8   38400
# 43                 TEXAS            19.5   40400
# 44                  UTAH            12.3   40800
# 45               VERMONT             4.4   42400
# 46              VIRGINIA            10.1   46500
# 47            WASHINGTON             7.1   50500
# 48         WEST VIRGINIA             4.2   39400
# 49             WISCONSIN             6.6   43400
# 50               WYOMING            18.2   50500

# %%
selection = alt.selection_single(empty = 'none', on = 'mouseover', nearest = True, fields = ['Income', 'Insurance_rate'])

color_condition = alt.condition(selection, alt.ColorValue('red'), alt.ColorValue('steelblue'))

scatter = alt.Chart(df).mark_circle(size = 100).encode(
    x= 'Income',
    y= 'Insurance_rate',
    color = color_condition,
    tooltip = ['Location', 'Insurance_rate', 'Income']
).properties(
    width=600,
    height=400
).add_selection(
    selection
)
scatter
# Out:
# alt.Chart(...)

# %%
# top histogram
top_hist = alt.Chart(df).mark_bar().encode(
    x = alt.X('Income:Q', bin = alt.Bin(maxbins = 10), axis = None, scale = alt.Scale(domain = [0, 65000])),
    y = alt.Y('count()', axis = None),
).properties(
    width=600,
    height=50
)

# density line
top_line = alt.Chart(df).transform_density(
    'Income',
    as_ = ['Income', 'density'],
    extent = [0, 65000]
).mark_line().encode(
    x = alt.X('Income:Q', axis = None, scale = alt.Scale(domain = [0, 65000])),
    y = alt.Y('density:Q', axis = None),
    color = alt.value('red')
).properties(
    width=600,
    height=50
)

vlines = alt.Chart(df).mark_rule(color = 'red').encode(
    x = alt.X('Income:Q', axis = None, scale = alt.Scale(domain = [0, 65000])),
    size = alt.value(4),
    opacity = alt.condition(selection, alt.value(1), alt.value(0))
).properties(
    width=600,
    height=50
).add_selection(
    selection
)

top = (top_hist + top_line + vlines).resolve_scale(y = 'independent')
top
# Out:
# alt.LayerChart(...)

# %%
# right histogram
right_hist = alt.Chart(df).mark_bar().encode(
    y = alt.Y('Insurance_rate:Q', bin = alt.Bin(maxbins = 10), axis = None, scale = alt.Scale(domain = [0, 22])),
    x = alt.X('count()', axis = None),
).properties(
    width=50,
    height=400
)

# density line
right_line = alt.Chart(df).transform_density(
    'Insurance_rate',
    as_ = ['Insurance_rate', 'density'],
    extent = [0, 22]
).mark_line(orient = alt.Orientation('horizontal')).encode(
    y = alt.Y('Insurance_rate:Q', axis = None, scale = alt.Scale(domain = [0, 22])),
    x = alt.X('density:Q', axis = None),
    color = alt.value('red')
).properties(
    width=50,
    height=400
)

hlines = alt.Chart(df).mark_rule(color = 'red').encode(
    y = alt.Y('Insurance_rate:Q', axis = None, scale = alt.Scale(domain = [0, 22])),
    size = alt.value(4),
    opacity = alt.condition(selection, alt.value(1), alt.value(0)),
).properties(
    width=50,
    height=400
).add_selection(
    selection
)

right = (right_hist + right_line + hlines).resolve_scale(x = 'independent')
right
# Out:
# alt.LayerChart(...)

# %%
output = top & (scatter| right).resolve_scale(y = 'shared')
output.properties(title = 'Insurance Rate vs. Income for Disabled People in the US')
# Out:
# alt.VConcatChart(...)

# %%
st.altair_chart(output)
