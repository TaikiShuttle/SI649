# %%
import pandas as pd
import numpy as np
import altair as alt
import streamlit as st

# %%
df1 = pd.read_csv('insurance.csv')
df2 = pd.read_csv('income.csv')
df3 = pd.read_csv('healthy.csv')

df = pd.merge(df1, df2, on='Location')
df = df[['Location', 'Estimate (%)',  'Estimate ($)']]
df.columns = ['Location', 'Insurance_rate', 'Income']
df['Disabled'] = True
df
# Out:
#                 Location  Insurance_rate  Income  Disabled
# 0                ALABAMA            14.5   40400      True
# 1                 ALASKA            11.1   46800      True
# 2                ARIZONA            11.0   39200      True
# 3               ARKANSAS             7.4   35400      True
# 4             CALIFORNIA             7.6   48500      True
# 5               COLORADO             8.1   47500      True
# 6            CONNECTICUT             5.0   50500      True
# 7               DELAWARE             7.0   50500      True
# 8   DISTRICT OF COLUMBIA             2.9   60600      True
# 9                FLORIDA            15.1   38400      True
# 10               GEORGIA            16.5   40400      True
# 11                HAWAII             6.7   50500      True
# 12                 IDAHO            11.7   40400      True
# 13              ILLINOIS             7.4   43900      True
# 14               INDIANA             8.9   40400      True
# 15                  IOWA             5.1   40400      True
# 16                KANSAS            14.5   40400      True
# 17              KENTUCKY             4.9   37400      True
# 18             LOUISIANA             8.5   40400      True
# 19                 MAINE             7.6   39800      True
# 20              MARYLAND             5.5   54500      True
# 21         MASSACHUSETTS             3.6   52500      True
# 22              MICHIGAN             6.3   40400      True
# 23             MINNESOTA             6.6   48500      True
# 24           MISSISSIPPI            16.5   32300      True
# 25              MISSOURI            14.5   37400      True
# 26               MONTANA            10.6   37400      True
# 27              NEBRASKA            17.4   48500      True
# 28                NEVADA            12.0   40400      True
# 29         NEW HAMPSHIRE             8.8   51500      True
# 30            NEW JERSEY             7.6   50500      True
# 31            NEW MEXICO             9.3   38800      True
# 32              NEW YORK             4.5   48500      True
# 33        NORTH CAROLINA            14.1   38400      True
# 34          NORTH DAKOTA            12.6   44400      True
# 35                  OHIO             8.0   40400      True
# 36              OKLAHOMA            21.4   38400      True
# 37                OREGON             7.4   40400      True
# 38          PENNSYLVANIA             6.6   40400      True
# 39          RHODE ISLAND             3.0   50500      True
# 40        SOUTH CAROLINA            15.1   40400      True
# 41          SOUTH DAKOTA            17.7   36400      True
# 42             TENNESSEE            13.8   38400      True
# 43                 TEXAS            19.5   40400      True
# 44                  UTAH            12.3   40800      True
# 45               VERMONT             4.4   42400      True
# 46              VIRGINIA            10.1   46500      True
# 47            WASHINGTON             7.1   50500      True
# 48         WEST VIRGINIA             4.2   39400      True
# 49             WISCONSIN             6.6   43400      True
# 50               WYOMING            18.2   50500      True

# %%
dff = pd.merge(df2, df3, on = 'Location')
dff = dff[['Location', 'Estimate (%)', 'Estimate ($)']]
dff.columns = ['Location', 'Insurance_rate', 'Income']
dff['Disabled'] = False
dff
# Out:
#                 Location  Insurance_rate  Income  Disabled
# 0                ALABAMA            14.6   40400     False
# 1                 ALASKA            15.2   46800     False
# 2                ARIZONA            15.6   39200     False
# 3               ARKANSAS            14.0   35400     False
# 4             CALIFORNIA            11.2   48500     False
# 5               COLORADO            10.6   47500     False
# 6            CONNECTICUT             8.6   50500     False
# 7               DELAWARE             9.5   50500     False
# 8   DISTRICT OF COLUMBIA             4.2   60600     False
# 9                FLORIDA            19.7   38400     False
# 10               GEORGIA            18.6   40400     False
# 11                HAWAII             5.1   50500     False
# 12                 IDAHO            16.2   40400     False
# 13              ILLINOIS            10.5   43900     False
# 14               INDIANA            11.9   40400     False
# 15                  IOWA             7.1   40400     False
# 16                KANSAS            12.6   40400     False
# 17              KENTUCKY             9.6   37400     False
# 18             LOUISIANA            13.7   40400     False
# 19                 MAINE            12.1   39800     False
# 20              MARYLAND             8.5   54500     False
# 21         MASSACHUSETTS             4.4   52500     False
# 22              MICHIGAN             8.6   40400     False
# 23             MINNESOTA             6.5   48500     False
# 24           MISSISSIPPI            19.7   32300     False
# 25              MISSOURI            14.0   37400     False
# 26               MONTANA            11.8   37400     False
# 27              NEBRASKA            10.4   48500     False
# 28                NEVADA            15.8   40400     False
# 29         NEW HAMPSHIRE             9.0   51500     False
# 30            NEW JERSEY            11.3   50500     False
# 31            NEW MEXICO            15.2   38800     False
# 32              NEW YORK             7.9   48500     False
# 33        NORTH CAROLINA            16.6   38400     False
# 34          NORTH DAKOTA             8.0   44400     False
# 35                  OHIO             9.2   40400     False
# 36              OKLAHOMA            21.2   38400     False
# 37                OREGON            10.5   40400     False
# 38          PENNSYLVANIA             7.9   40400     False
# 39          RHODE ISLAND             6.4   50500     False
# 40        SOUTH CAROLINA            15.8   40400     False
# 41          SOUTH DAKOTA            13.2   36400     False
# 42             TENNESSEE            14.8   38400     False
# 43                 TEXAS            24.5   40400     False
# 44                  UTAH            12.0   40800     False
# 45               VERMONT             7.3   42400     False
# 46              VIRGINIA            10.9   46500     False
# 47            WASHINGTON             9.4   50500     False
# 48         WEST VIRGINIA            10.9   39400     False
# 49             WISCONSIN             8.2   43400     False
# 50               WYOMING            16.2   50500     False

# %%
df = pd.concat([df, dff])
df
# Out:
#          Location  Insurance_rate  Income  Disabled
# 0         ALABAMA            14.5   40400      True
# 1          ALASKA            11.1   46800      True
# 2         ARIZONA            11.0   39200      True
# 3        ARKANSAS             7.4   35400      True
# 4      CALIFORNIA             7.6   48500      True
# ..            ...             ...     ...       ...
# 46       VIRGINIA            10.9   46500     False
# 47     WASHINGTON             9.4   50500     False
# 48  WEST VIRGINIA            10.9   39400     False
# 49      WISCONSIN             8.2   43400     False
# 50        WYOMING            16.2   50500     False
#
# [102 rows x 4 columns]

# %%
selection = alt.selection_single(empty = 'none', on = 'mouseover', nearest = True, fields = ['Income', 'Insurance_rate'])

subgroup = alt.selection_single(name = 'subgroup', fields = ['Disabled'], init = {'Disabled': True}, bind = alt.binding_radio(options = [True, False]))

color_condition = alt.condition(selection, alt.ColorValue('red'), alt.ColorValue('steelblue'))

scatter = alt.Chart(df).transform_filter(subgroup).mark_circle(size = 100).encode(
    x= alt.X('Income', title = 'Income ($)'),
    y= alt.Y('Insurance_rate', title = 'Insurance Rate (%)'),
    color = color_condition,
    tooltip = ['Location', 'Insurance_rate', 'Income']
).properties(
    width=600,
    height=400
).add_selection(
    selection, subgroup
)
scatter
# Out:
# alt.Chart(...)

# %%
# top histogram
top_hist = alt.Chart(df).transform_filter(subgroup).mark_bar().encode(
    x = alt.X('Income:Q', bin = alt.Bin(maxbins = 10), axis = None, scale = alt.Scale(domain = [0, 65000])),
    y = alt.Y('count()', axis = None),
).properties(
    width=600,
    height=50
).add_selection(
    subgroup
)

# density line
top_line = alt.Chart(df).transform_filter(subgroup).transform_density(
    'Income',
    as_ = ['Income', 'density'],
    extent = [0, 65000]
).mark_line().encode(
    x = alt.X('Income:Q', axis = None, scale = alt.Scale(domain = [0, 65000])),
    y = alt.Y('density:Q', axis = None),
    color = alt.value('red')
).properties(
    width=600,
    height=50
)

vlines = alt.Chart(df).transform_filter(subgroup).mark_rule(color = 'red').encode(
    x = alt.X('Income:Q', axis = None, scale = alt.Scale(domain = [0, 65000])),
    size = alt.value(4),
    opacity = alt.condition(selection, alt.value(1), alt.value(0))
).properties(
    width=600,
    height=50
).add_selection(
    selection
)

top = (top_hist + top_line + vlines).resolve_scale(y = 'independent')
top
# Out:
# alt.LayerChart(...)

# %%
# right histogram
right_hist = alt.Chart(df).transform_filter(subgroup).mark_bar().encode(
    y = alt.Y('Insurance_rate:Q', bin = alt.Bin(maxbins = 10), axis = None, scale = alt.Scale(domain = [0, 26])),
    x = alt.X('count()', axis = None),
).properties(
    width=50,
    height=400
).add_selection(
    subgroup
)

# density line
right_line = alt.Chart(df).transform_filter(subgroup).transform_density(
    'Insurance_rate',
    as_ = ['Insurance_rate', 'density'],
    extent = [0, 26]
).mark_line(orient = alt.Orientation('horizontal')).encode(
    y = alt.Y('Insurance_rate:Q', axis = None, scale = alt.Scale(domain = [0, 26])),
    x = alt.X('density:Q', axis = None),
    color = alt.value('red')
).properties(
    width=50,
    height=400
)

hlines = alt.Chart(df).transform_filter(subgroup).mark_rule(color = 'red').encode(
    y = alt.Y('Insurance_rate:Q', axis = None, scale = alt.Scale(domain = [0, 26])),
    size = alt.value(4),
    opacity = alt.condition(selection, alt.value(1), alt.value(0)),
).properties(
    width=50,
    height=400
).add_selection(
    selection
)

right = (right_hist + right_line + hlines).resolve_scale(x = 'independent')
right
# Out:
# alt.LayerChart(...)

# %%
output = top & (scatter| right).resolve_scale(y = 'shared')
output.properties(title = 'Insurance Rate vs. Income for Disabled People in the US')
# Out:
# alt.VConcatChart(...)

# %%
st.altair_chart(output)
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)
